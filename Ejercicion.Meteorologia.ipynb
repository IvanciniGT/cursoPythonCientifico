# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn

# %%
datos=pd.read_csv(r'.\austin_weather.csv')

# %%
datos.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
datos.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF
# count  1319.000000  1319.000000  1319.000000
# mean     80.862775    70.642911    59.902957
# std      14.766523    14.045904    14.190648
# min      32.000000    29.000000    19.000000
# 25%      72.000000    62.000000    49.000000
# 50%      83.000000    73.000000    63.000000
# 75%      92.000000    83.000000    73.000000
# max     107.000000    93.000000    81.000000

# %%
datos.shape
# Out:
# (1319, 21)

# %%
datos.dtypes
# Out:
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# WindAvgMPH                    object
# WindGustMPH                   object
# PrecipitationSumInches        object
# Events                        object
# dtype: object

# %%
datos['DewPointHighF'].describe()
# Out:
# count     1319
# unique      64
# top         74
# freq       112
# Name: DewPointHighF, dtype: object

# %%
datos['DewPointLowF'].unique()
# Out:
# array(['43', '28', '23', '21', '36', '33', '37', '30', '19', '18', '38',
#        '15', '2', '4', '50', '54', '20', '17', '16', '24', '10', '22',
#        '5', '7', '9', '51', '41', '27', '39', '13', '29', '53', '32',
#        '59', '44', '47', '35', '48', '12', '26', '31', '45', '52', '56',
#        '49', '62', '63', '66', '60', '61', '55', '57', '25', '67', '58',
#        '65', '68', '69', '64', '-', '70', '71', '46', '40', '34', '14',
#        '42', '8', '72', '73', '75', '6', '11'], dtype=object)

# %%
for columna in datos.columns[1:-1]:
    print(columna + ": " + str(datos[columna].unique()))
# Out:
# TempHighF: [ 74  56  58  61  57  60  62  64  44  55  69  71  59  36  48  53  70  72
#   75  67  76  82  63  40  39  49  65  80  46  32  38  86  81  83  77  52
#   73  47  50  68  66  89  79  85  84  87  78  88  96  93  94  91  92  90
#   95  97  98 100 101  99 102 104 103  51  41  45  54  42  43  37 105  34
#  107 106]
# TempAvgF: [60 48 45 46 50 53 51 40 54 44 43 57 47 29 35 62 65 52 56 59 64 42 33 38
#  68 66 34 67 70 69 73 63 74 36 49 61 55 58 72 76 77 75 78 85 80 79 83 81
#  82 92 84 86 87 88 90 89 91 71 39 37 41 30 32 93]
# TempLowF: [45 39 32 31 41 40 36 35 33 28 42 34 22 53 57 48 46 43 37 38 27 26 55 29
#  47 59 58 63 62 52 44 24 30 50 56 49 51 54 61 60 66 70 71 65 68 64 67 73
#  72 74 75 76 77 78 69 79 80 23 81 19 21]
# DewPointHighF: ['67' '43' '31' '36' '44' '39' '41' '49' '51' '37' '55' '54' '15' '29'
#  '60' '64' '58' '28' '42' '22' '38' '45' '19' '59' '62' '40' '17' '53'
#  '34' '48' '52' '61' '63' '33' '57' '65' '46' '32' '50' '27' '56' '47'
# ...

# %%
datos=datos.replace('-',-1000).replace('T',-1000)

# %%
for columna in datos.columns[1:-1]:
    print(columna + ": " + str(datos[columna].unique()))
# Out:
# TempHighF: [ 74  56  58  61  57  60  62  64  44  55  69  71  59  36  48  53  70  72
#   75  67  76  82  63  40  39  49  65  80  46  32  38  86  81  83  77  52
#   73  47  50  68  66  89  79  85  84  87  78  88  96  93  94  91  92  90
#   95  97  98 100 101  99 102 104 103  51  41  45  54  42  43  37 105  34
#  107 106]
# TempAvgF: [60 48 45 46 50 53 51 40 54 44 43 57 47 29 35 62 65 52 56 59 64 42 33 38
#  68 66 34 67 70 69 73 63 74 36 49 61 55 58 72 76 77 75 78 85 80 79 83 81
#  82 92 84 86 87 88 90 89 91 71 39 37 41 30 32 93]
# TempLowF: [45 39 32 31 41 40 36 35 33 28 42 34 22 53 57 48 46 43 37 38 27 26 55 29
#  47 59 58 63 62 52 44 24 30 50 56 49 51 54 61 60 66 70 71 65 68 64 67 73
#  72 74 75 76 77 78 69 79 80 23 81 19 21]
# DewPointHighF: ['67' '43' '31' '36' '44' '39' '41' '49' '51' '37' '55' '54' '15' '29'
#  '60' '64' '58' '28' '42' '22' '38' '45' '19' '59' '62' '40' '17' '53'
#  '34' '48' '52' '61' '63' '33' '57' '65' '46' '32' '50' '27' '56' '47'
# ...

# %%
datos['PrecipitationSumInches']=datos['PrecipitationSumInches'].astype(np.float64)
# Out:
# dtype('float64')

# %%
datos['PrecipitationSumInches'].dtype
# Out:
# dtype('O')

# %%
for columna in datos.columns[1:-1]:
    datos[columna]=datos[columna].astype(np.float64)

# %%
datos.dtypes
# Out:
# Date                           object
# TempHighF                     float64
# TempAvgF                      float64
# TempLowF                      float64
# DewPointHighF                 float64
# DewPointAvgF                  float64
# DewPointLowF                  float64
# HumidityHighPercent           float64
# HumidityAvgPercent            float64
# HumidityLowPercent            float64
# SeaLevelPressureHighInches    float64
# SeaLevelPressureAvgInches     float64
# SeaLevelPressureLowInches     float64
# VisibilityHighMiles           float64
# VisibilityAvgMiles            float64
# VisibilityLowMiles            float64
# WindHighMPH                   float64
# WindAvgMPH                    float64
# WindGustMPH                   float64
# PrecipitationSumInches        float64
# Events                         object
# dtype: object

# %%
datos.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF  DewPointHighF  DewPointAvgF  \
# count  1319.000000  1319.000000  1319.000000    1319.000000   1319.000000
# mean     80.862775    70.642911    59.902957      55.881729     51.025019
# std      14.766523    14.045904    14.190648      78.335499     78.217869
# min      32.000000    29.000000    19.000000   -1000.000000  -1000.000000
# 25%      72.000000    62.000000    49.000000      52.000000     46.000000
# 50%      83.000000    73.000000    63.000000      66.000000     61.000000
# 75%      92.000000    83.000000    73.000000      73.000000     69.000000
# max     107.000000    93.000000    81.000000      80.000000     76.000000
#
#        DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# count   1319.000000          1319.000000         1319.000000
# mean      45.356331            86.222896           65.054587
# std       78.073001            43.758376           43.347749
# ...

# %%
datos['DewPointHighF'][datos['DewPointHighF']!=-1000].describe()
# Out:
# count    1312.000000
# mean       61.515244
# std        13.586452
# min        13.000000
# 25%        53.000000
# 50%        66.000000
# 75%        73.000000
# max        80.000000
# Name: DewPointHighF, dtype: float64

# %%
for columna in datos.columns[1:-1]:
    print(datos[columna][datos[columna]!=-1000].describe())
# Out:
# count    1319.000000
# mean       80.862775
# std        14.766523
# min        32.000000
# 25%        72.000000
# 50%        83.000000
# 75%        92.000000
# max       107.000000
# Name: TempHighF, dtype: float64
# count    1319.000000
# mean       70.642911
# std        14.045904
# min        29.000000
# 25%        62.000000
# 50%        73.000000
# 75%        83.000000
# max        93.000000
# Name: TempAvgF, dtype: float64
# count    1319.000000
# mean       59.902957
# std        14.190648
# min        19.000000
# 25%        49.000000
# 50%        63.000000
# 75%        73.000000
# max        81.000000
# Name: TempLowF, dtype: float64
# count    1312.000000
# mean       61.515244
# std        13.586452
# min        13.000000
# 25%        53.000000
# 50%        66.000000
# 75%        73.000000
# max        80.000000
# Name: DewPointHighF, dtype: float64
# count    1312.000000
# mean       56.632622
# std        14.866272
# min         8.000000
# 25%        46.000000
# ...

# %%
for columna in datos.columns[1:-1]:
    fig,axs=mpl.pyplot.subplots(1,2,figsize=(12,3))
    seaborn.distplot(datos[columna][datos[columna]!=-1000],ax=axs[0])
    seaborn.boxplot(datos[columna][datos[columna]!=-1000],ax=axs[1])
    mpl.pyplot.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# estadisticos=datos['TempHighF'].describe()
# estadisticos

# %%
maximo=estadisticos['mean']+3*estadisticos['std']
minimo=estadisticos['mean']-3*estadisticos['std']
extremos=datos['TempHighF'].apply(lambda valor: 1 if valor<minimo or valor > maximo else 0)
extremos[extremos==1]
# Out:
# 16      1
# 47      1
# 52      1
# 383     1
# 385     1
# 433     1
# 434     1
# 1112    1
# Name: TempHighF, dtype: int64

# %%
for indice in extremos[extremos==1].index:
    print(datos['TempHighF'].iloc[indice])
# Out:
# 36.0
# 32.0
# 36.0
# 36.0
# 36.0
# 36.0
# 36.0
# 34.0

# %%
precipitaciones=datos['PrecipitationSumInches'][datos['PrecipitationSumInches']!=-1000]

estadisticos=precipitaciones.describe()
maximo=estadisticos['75%']+1.5*(estadisticos['75%']-estadisticos['25%'])
minimo=estadisticos['25%']-1.5*(estadisticos['75%']-estadisticos['25%'])
extremos=precipitaciones.apply(lambda valor: 1 if valor<minimo or valor > maximo else 0)
extremos
for indice in extremos[extremos==1].index:
    print(datos['PrecipitationSumInches'].iloc[indice])
extremos[extremos==1].shape
# Out:
# 0.46
# 0.16
# 0.1
# 0.06
# 0.05
# 0.05
# 0.15
# 0.1
# 0.11
# 0.08
# 0.08
# 0.17
# 0.74
# 0.11
# 0.07
# 0.2
# 0.27
# 1.34
# 0.06
# 0.06
# 2.45
# 0.94
# 0.14
# 0.19
# 1.56
# 1.75
# 0.55
# 1.49
# 0.27
# 0.24
# 0.49
# 0.07
# 0.06
# 0.31
# 3.53
# 1.52
# 0.09
# 0.05
# 0.07
# 0.98
# 0.19
# 0.22
# 0.51
# 0.68
# 0.35
# 3.66
# 0.13
# 0.21
# 0.03
# 1.42
# 0.09
# 0.3
# 0.56
# 1.51
# 0.04
# 0.33
# 3.33
# 0.06
# 0.04
# 0.07
# 0.1
# 0.59
# 0.03
# 0.13
# 0.63
# 0.2
# 0.76
# 0.3
# 0.17
# 0.16
# 2.07
# 0.4
# 0.31
# 0.26
# 0.06
# 0.1
# 0.09
# 0.15
# 0.13
# 0.45
# 2.17
# 0.13
# 1.17
# 0.43
# 0.05
# 0.09
# 0.09
# 0.41
# 0.57
# 0.43
# 0.04
# 0.08
# 0.56
# 3.84
# 0.29
# 0.4
# 0.23
# 1.12
# 0.08
# 0.36
# 2.6
# 0.33
# 0.03
# 1.41
# 0.76
# 5.2
# 0.2
# 0.67
# 1.34
# 0.19
# 1.34
# 2.66
# 1.09
# 0.49
# 0.93
# 0.08
# 0.75
# 0.35
# 1.05
# 0.79
# 0.04
# 0.16
# 0.43
# 4.79
# 0.65
# 4.93
# 0.89
# 0.07
# 0.05
# 0.53
# 1.03
# 0.26
# 1.46
# 0.25
# 0.04
# 1.54
# 0.1
# 1.32
# 0.03
# 0.2
# 0.13
# 1.33
# 0.22
# 2.18
# 0.4
# ...

# %%
datos['Date']=datos['Date'].apply(lambda texto: pd.Timestamp(texto))

# %%
datos['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
datos_filtrados=datos[datos['PrecipitationSumInches']!=-1000]
mpl.pyplot.plot(datos_filtrados['Date'],datos_filtrados['PrecipitationSumInches'].cumsum())

# %%
def saca_por_fecha(dataframe,anyo):
    datos_extraidos=dataframe[ dataframe['Date']<=pd.Timestamp(anyo+'-12-31')]
    return datos_extraidos[datos_extraidos['Date']>=pd.Timestamp(anyo+'-01-01') ]

datos_filtrados=datos[datos['PrecipitationSumInches']!=-1000]
datos_2014=saca_por_fecha(datos_filtrados,'2014')
datos_2015=saca_por_fecha(datos_filtrados,'2015')
datos_2016=saca_por_fecha(datos_filtrados,'2016')
datos_2017=saca_por_fecha(datos_filtrados,'2017')
mpl.pyplot.plot(datos_2014['Date'],datos_2014['PrecipitationSumInches'].cumsum())
mpl.pyplot.plot(datos_2015['Date'],datos_2015['PrecipitationSumInches'].cumsum())
mpl.pyplot.plot(datos_2016['Date'],datos_2016['PrecipitationSumInches'].cumsum())
mpl.pyplot.plot(datos_2017['Date'],datos_2017['PrecipitationSumInches'].cumsum())

# %%
datos_2014
# Out:
#           Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 11  2014-01-01       69.0      54.0      39.0           51.0          42.0
# 12  2014-01-02       55.0      44.0      33.0           39.0          26.0
# 13  2014-01-03       58.0      43.0      28.0           37.0          22.0
# 14  2014-01-04       71.0      57.0      42.0           55.0          48.0
# 15  2014-01-05       59.0      47.0      34.0           54.0          32.0
# ..         ...        ...       ...       ...            ...           ...
# 370 2014-12-26       74.0      64.0      53.0           63.0          57.0
# 371 2014-12-27       66.0      54.0      41.0           63.0          49.0
# 372 2014-12-28       47.0      40.0      32.0           34.0          30.0
# 373 2014-12-29       67.0      49.0      30.0           42.0          36.0
# 374 2014-12-30       46.0      43.0      39.0           43.0          40.0
#
#      DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# ...
